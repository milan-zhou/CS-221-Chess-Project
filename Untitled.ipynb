# %%
import sys
sys.path.append('python-chess')
sys.path.append('players')
import player
import game
import time
import chess

def betterEvaluate(state, role):
#     d = {1: 1, 2: 3, 3: 3, 4: 5, 5: 9}
#     valueScore = 0
#     for key in d:
#         valueScore += d[key] * (len(state.pieces(key, role)) - len(state.pieces(key, not role)))
    mobility = len(state.legal_moves)
    state.push(player.getLegalMove(state))
    mobility2 = len(state.legal_moves)
    state.pop()
    mobilityScore = mobility - mobility2 if role == state.turn else mobility2 - mobility
    print(mobilityScore)

# %%
state = chess.Board()
for i in range(100):
    state.push(player.getLegalMove(state))
    print(betterEvaluate(state, True))
    print(state)
# Out:
# 0
# None
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
# 1
# None
# r n b q k b . r
# p p p p p p p p
# . . . . . . . n
# . . . . . . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
# 6
# None
# r n b q k b . r
# p p p p p p p p
# . . . . . . . n
# . . . . . . N .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
# 6
# None
# r n b q k b r .
# p p p p p p p p
# . . . . . . . n
# . . . . . . N .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
# 3
# None
# r n b q k b r .
# p p p p p p p N
# . . . . . . . n
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
# -1
# None
# r n b q k b . r
# p p p p p p p N
# . . . . . . . n
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
# 0
# None
# r n b q k N . r
# p p p p p p p .
# . . . . . . . n
# ...
