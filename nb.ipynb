# %%
import sys
sys.path.append('python-chess')
import chess
import chess.uci
import random
import time
import cProfile
import numpy as np
sys.path.append('players')
import player
import evaluate
import game

# %%
def play(state, p1, p2, timeLimit, verbose = False):
    while True:
        if verbose:
            print()
            print(state)
            print()
        
        result = game.gameOver(state)
        if (result != "*"):
            return result

        whiteMove = p1.getMove(state, timeLimit)
        print(whiteMove, p1.nodes)
        state.push(whiteMove)
        
        if verbose:
            print()
            print(state)
            print()
        
        result = game.gameOver(state)
        if (result != "*"):
            return result

        blackMove = p2.getMove(state, timeLimit)

        state.push(blackMove)
        
def evaluatePlayers(p1, p2, n, timeLimit, verbose=False):
    state = chess.Board()
    white = 0
    black = 0
    for i in range(n):
        result = play(state, p1 , p2, 10, verbose)
        if result == "1-0":
            white += 1
        elif result == "0-1":
            black += 1
        else:
            white += .5
            black += .5
        state.reset()
    print(white,black)

# %%
import alphabeta
p1 = alphabeta.alphabetaPlayer(evaluate.simpleEvaluate, True)
p2 = player.randomPlayer(evaluate.simpleEvaluate, False)
evaluatePlayers(p1,p2, 1, 10, True)

# %%
import mtd
p1 = mtd.mtdPlayer(evaluate.simpleEvaluate, True)
p2 = player.randomPlayer(evaluate.simpleEvaluate, False)

evaluatePlayers(p1,p2, 1, 10, True)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
# 2 g1h3 0
# 4 g1h3 0
# 6 None -inf
# g1h3 15506
#
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b n r
# p p p p . p p p
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
# 2 h3g1 0
# 4 h3g5 -3
# h3g1 15747
#
# r n b q k b n r
# p p p p . p p p
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
#
# r n b q k b n r
# p . p p . p p p
# . p . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
# 2 g1h3 0
# 4 g1h3 -1
# 6 None -inf
# g1h3 15077
#
# r n b q k b n r
# p . p p . p p p
# . p . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k . n r
# p . p p . p p p
# . p . . . . . .
# . . . . p . . .
# . b . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
# 2 h3g1 -1
# 4 h3g1 -1
# 6 None -inf
# h3g1 16923
#
# r n b q k . n r
# p . p p . p p p
# . p . . . . . .
# . . . . p . . .
# . b . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
#
# r n b q k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
# 2 g1h3 -1
# 4 b1c3 -1
# 6 None -inf
# g1h3 16156
#
# r n b q k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b . k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . . .
# . . . . . . . q
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
# 2 h1g1 -3
# 4 g2g3 -1
# g2g3 18055
#
# r n b . k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . . .
# . . . . . . . q
# . . . . . . P N
# P P P P P P . P
# R N B Q K B . R
#
#
# r n b . k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . . .
# . . q . . . . .
# . . . . . . P N
# P P P P P P . P
# R N B Q K B . R
#
# 2 h3g5 -1
# 4 f1g2 -1
# h3g5 16479
#
# r n b . k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . N .
# . . q . . . . .
# . . . . . . P .
# P P P P P P . P
# R N B Q K B . R
#
#
# r n b . k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . N .
# . . . . q . . .
# . . . . . . P .
# P P P P P P . P
# R N B Q K B . R
#
# 2 g5e4 8
# 4 g5e4 7
# 6 g5h7 6
# g5e4 14371
#
# r n b . k . n r
# p . p p . p p p
# . p . . . . . .
# . . b . p . . .
# . . . . N . . .
# . . . . . . P .
# P P P P P P . P
# R N B Q K B . R
#
#
# r n b . k . n r
# p . p p . p p .
# . p . . . . . p
# . . b . p . . .
# . . . . N . . .
# . . . . . . P .
# P P P P P P . P
# R N B Q K B . R
#
# 2 e4c5 9
# 4 e4c5 9
# 6 e4f6 8
# e4c5 14462
#
# r n b . k . n r
# p . p p . p p .
# . p . . . . . p
# . . N . p . . .
# . . . . . . . .
# . . . . . . P .
# P P P P P P . P
# R N B Q K B . R
#
#
# r . b . k . n r
# p . p p . p p .
# . p n . . . . p
# . . N . p . . .
# . . . . . . . .
# . . . . . . P .
# P P P P P P . P
# R N B Q K B . R
#
# 2 c5e4 12
# 4 c5d7 11
# c5e4 13030
#
# r . b . k . n r
# p . p p . p p .
# . p n . . . . p
# . . . . p . . .
# . . . . N . . .
# . . . . . . P .
# P P P P P P . P
# R N B Q K B . R
#
#
. . p . p p
# . . . . . . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
#
# . N . . . . . .
# p . k . . p . .
# . . n p . n . r
# . p . . p . p p
# . . . . . . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
# 2 b8c6 18
# 4 b8c6 17
# 6 b8d7 16
# b8c6 19752
#
# . . . . . . . .
# p . k . . p . .
# . . N p . n . r
# . p . . p . p p
# . . . . . . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
#
# . . . . . . . .
# . . k . . p . .
# . . N p . n . r
# p p . . p . p p
# . . . . . . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
# 2 c6a5 21
# 4 c6a7 19
# 6 c6d8 18
# c6a5 13879
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# N p . . p . p p
# . . . . . . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# N . . . p . p p
# . p . . . . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
# 2 a5c4 21
# 4 g2g1 21
# a5c4 14802
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# . . . . p . p p
# . p N . . . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# . . . . . . p p
# . p N . p . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
# 2 c4a5 21
# 4 g2g1 21
# c4a5 14061
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# N . . . . . p p
# . p . . p . b .
# . . . . . . P .
# P P P P P P R P
# R N B Q K B . .
#
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# N . . . . . p p
# . p . . p . . .
# . . . . . . P .
# P P P P b P R P
# R N B Q K B . .
#
# 2 f1e2 24
# 4 f1e2 24
# 6 a5b7 23
# f1e2 13524
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# N . . . . . p p
# . p . . p . . .
# . . . . . . P .
# P P P P B P R P
# R N B Q K . . .
#
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# N . . . . . p p
# . p . . . . . .
# . . . . p . P .
# P P P P B P R P
# R N B Q K . . .
#
# 2 f2e3 25
# 4 a5c4 24
# 6 None -inf
# f2e3 12462
#
# . . . . . . . .
# . . k . . p . .
# . . . p . n . r
# N . . . . . p p
# . p . . . . . .
# . . . . P . P .
# P P P P B . R P
# R N B Q K . . .
#
#
# . . . . . . . .
# . . k n . p . .
# . . . p . . . r
# N . . . . . p p
# . p . . . . . .
# . . . . P . P .
# P P P P B . R P
# R N B Q K . . .
#
# 2 a5c4 25
# 4 a5c4 25
# 6 None -inf
# a5c4 12810
#
# . . . . . . . .
# . . k n . p . .
# . . . p . . . r
# . . . . . . p p
# . p N . . . . .
# . . . . P . P .
# P P P P B . R P
# R N B Q K . . .
#
#
# . n . . . . . .
# . . k . . p . .
# . . . p . . . r
# . . . . . . p p
# . p N . . . . .
# . . . . P . P .
# P P P P B . R P
# R N B Q K . . .
#
# 2 c4a5 25
# 4 c4a5 25
# 6 c4d6 24
# c4a5 14967
#
# . n . . . . . .
# . . k . . p . .
# . . . p . . . r
# N . . . . . p p
# . p . . . . . .
# . . . . P . P .
# P P P P B . R P
# R N B Q K . . .
#
#
# . n . . . . . .
# . . k . . p . .
# . . . p . . r .
# N . . . . . p p
# . p . . . . . .
# . . . . P . P .
# P P P P B . R P
# R N B Q K . . .
#
# 2 e2h5 26
# 4 e2h5 26
# 6 a5b7 25
# e2h5 14767
#
# . n . . . . . .
# . . k . . p . .
# . . . p . . r .
# N . . . . . p B
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
#
# . n . k . . . .
# . . . . . p . .
# . . . p . . r .
# N . . . . . p B
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
# 2 h5g6 28
# 4 h5g6 28
# 6 h5g6 29
# h5g6 14926
#
# . n . k . . . .
# . . . . . p . .
# . . . p . . B .
# N . . . . . p .
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
#
# . n . . . . . .
# . . . . k p . .
# . . . p . . B .
# N . . . . . p .
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
# 2 g6h7 31
# 4 g6h7 31
# 6 None -inf
# g6h7 13420
#
# . n . . . . . .
# . . . . k p . B
# . . . p . . . .
# N . . . . . p .
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
#
# . n . . . k . .
# . . . . . p . B
# . . . p . . . .
# N . . . . . p .
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
# 2 h7f5 31
# 4 h7f5 31
# 6 h7g8 29
# h7f5 14087
#
# . n . . . k . .
# . . . . . p . .
# . . . p . . . .
# N . . . . B p .
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
#
# . . . . . k . .
# . . . n . p . .
# . . . p . . . .
# N . . . . B p .
# . p . . . . . .
# . . . . P . P .
# P P P P . . R P
# R N B Q K . . .
#
# 2 f5d7 34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a089dc24c4c7> in <module>()
#       3 p2 = player.randomPlayer(evaluate.simpleEvaluate, False)
#       4
# ----> 5 evaluatePlayers(p1,p2, 1, 10, True)
#
# <ipython-input-2-47a0a2cb7204> in evaluatePlayers(p1, p2, n, timeLimit, verbose)
#      32     black = 0
#      33     for i in range(n):
# ---> 34         result = play(state, p1 , p2, 10, verbose)
#      35         if result == "1-0":
#      36             white += 1
#
# <ipython-input-2-47a0a2cb7204> in play(state, p1, p2, timeLimit, verbose)
#      10             return result
#      11
# ---> 12         whiteMove = p1.getMove(state, timeLimit)
#      13         print(whiteMove, p1.nodes)
#      14         state.push(whiteMove)
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/players/mtd.py in getMove(self, state, timeLimit)
#     152         while (time.time() < stopTime):
#     153             depth +=2
# --> 154             move, guess = self._mtd(state, depth, guess, stopTime)
#     155             print(depth, move, guess)
#     156
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/players/mtd.py in _mtd(self, state, maxDepth, firstGuess, stopTime)
#     131             else:
#     132                 beta = g
# --> 133             move, g = self.alphaBetaWithMemory(state, beta - 1, beta, maxDepth, True, stopTime, root=True)
#     134
#     135             if g < beta:
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/players/mtd.py in alphaBetaWithMemory(self, state, alpha, beta, depth, isMax, stopTime, root)
#      70
#      71                 state.push(move)
# ---> 72                 minMove, score = self.alphaBetaWithMemory(state, a, beta, depth-1, not isMax, stopTime, root = False)
#      73                 state.pop()
#      74
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/players/mtd.py in alphaBetaWithMemory(self, state, alpha, beta, depth, isMax, stopTime, root)
#      92
#      93                 state.push(move)
# ---> 94                 maxMove, score = self.alphaBetaWithMemory(state, alpha, b, depth - 1, not isMax, stopTime, root = False)
#      95                 state.pop()
#      96
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/players/mtd.py in alphaBetaWithMemory(self, state, alpha, beta, depth, isMax, stopTime, root)
#      70
#      71                 state.push(move)
# ---> 72                 minMove, score = self.alphaBetaWithMemory(state, a, beta, depth-1, not isMax, stopTime, root = False)
#      73                 state.pop()
#      74
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/players/mtd.py in alphaBetaWithMemory(self, state, alpha, beta, depth, isMax, stopTime, root)
#      48         self.nodes += 1
#      49
# ---> 50         zhash = zobrist_hash(state)
#      51         entry = self.tp_score.get((zhash, depth, root), Entry(float("-inf"), float("inf"), None))
#      52         if entry.lower >= beta and (not root or entry.best):
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/polyglot.py in zobrist_hash(board, _hasher)
#     291     squares.
#     292     """
# --> 293     return _hasher(board)
#     294
#     295
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/polyglot.py in __call__(self, board)
#     279     def __call__(self, board):
#     280         return (self.hash_board(board) ^ self.hash_castling(board) ^
# --> 281                 self.hash_ep_square(board) ^ self.hash_turn(board))
#     282
#     283
#
# ~/Files/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/polyglot.py in hash_board(self, board)
#     239             for square in chess.scan_reversed(squares):
#     240                 piece_index = (board.piece_type_at(square) - 1) * 2 + pivot
# --> 241                 zobrist_hash ^= self.array[64 * piece_index + square]
#     242
#     243         return zobrist_hash
#
# KeyboardInterrupt:
