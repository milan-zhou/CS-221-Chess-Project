# %%
import sys
sys.path.append('python-chess')
import chess
import chess.uci
import random
import time
import cProfile
import numpy as np

# %%
def simpleHeuristic(state, result = None, role = None):
    d = {1: 1, 2: 3, 3: 3, 4: 5, 5: 9}
    heuristicScore = 0
    for i in range(1, 6):
        heuristicScore += d[i] * (len(state.pieces(i, True)) - len(state.pieces(i, False)))
    if (state.is_check()):
        heuristicScore += .5
    if not state.turn:
        heuristicScore = -heuristicScore
    return heuristicScore

def reward(state, result, role):
    if role:
        return -100 if result == "0-1" else -100
    else:
        return 100 if result == "1-0" else -1000
    
def monteCarloHeuristic(state, depth, role):
    result = state.is_game_over(True)
    if result != "*":
        return reward(state, result, role)
    elif not depth:
        return simpleHeuristic(state)
    randomMove = randomMove(state)
    state.push(randomMove)
    score = monteCarloHeuristic(state,depth-1,role)
    state.pop()
    return score

class player():
    def __init__(self, depth = 1, heuristic = simpleHeuristic, verbose = False):
        self.depth = depth
        self.heuristic = heuristic
        self.verbose = verbose

def gameOver(state):
    return state.result(True)

def randomMove(state):
    moves = state.legal_moves
    numMoves = len(moves)
    moveNumber = random.randint(0, numMoves-1)
    for i, move in enumerate(moves):
        if i == moveNumber:
            return move
        
class randomPlayer(player):
    def getMove(self, state):
        return randomMove(state)

class minimaxPlayer(player):
    def maxScore(self,state, depth):
        result = gameOver(state)
        if result != "*":
            return (None, reward(state, result, state.turn))
        if not depth:
            return (None, self.heuristic(state))
        moves = state.legal_moves
        bestScore = float("-inf")
        for i, move in enumerate(moves):
            state.push(move)
            testScore = self.minScore(state, depth)
            if testScore > bestScore:
                bestMove = move
                bestScore = testScore
                if bestScore == 100:
                    state.pop()
                    break
            state.pop()
            
        return (bestMove, bestScore)
            
            
    def minScore(self, state, depth):
        result = gameOver(state)
        if result != "*":
            return reward(state, result, state.turn)
            
        moves = state.legal_moves
        worstScore = float("inf")
        for i, move in enumerate(moves):
            state.push(move)
            testMove, testScore = self.maxScore(state, depth - 1)
            if testScore < worstScore:
                worstScore = testScore
                if worstScore == -100:
                    state.pop()
                    break
            state.pop()
        return worstScore
    
    def getMove(self, state):
        bestMove, bestScore = self.maxScore(state, self.depth)
        return bestMove
    
class alphabetaPlayer(player):
    def maxScore(self,state, alpha, beta, depth):
        result = gameOver(state)
        if result != "*":
            return (None, reward(state, result, state.turn))
        if not depth:
            return (None, self.heuristic(state, 100, state.turn))
        moves = state.legal_moves
        bestMove = None
        for i, move in enumerate(moves):
            state.push(move)
            testScore = self.minScore(state, alpha, beta, depth)
            if testScore > alpha:
                bestMove = move
                alpha = testScore
                if alpha >= beta:
                    state.pop()
                    break
            state.pop()
            
        return (bestMove, alpha)
            
            
    def minScore(self, state, alpha, beta, depth):
        result = gameOver(state)
        if result != "*":
            return reward(state, result, state.turn)
            
        moves = state.legal_moves
        for i, move in enumerate(moves):
            state.push(move)
            testMove, testScore = self.maxScore(state, alpha, beta, depth - 1)
            if testScore < beta:
                beta = testScore
                if beta <= alpha:
                    state.pop()
                    break
            state.pop()
        return beta
    
    def getMove(self, state):
        bestMove, bestScore = self.maxScore(state, -100, 100, self.depth)
        return bestMove

# %%
def play(state, p1, p2, verbose = False):
    while True:
        if verbose:
            print()
            print(state)
            print()
        
        result = gameOver(state)
        if (result != "*"):
            return result

        whiteMove = p1.getMove(state)

        state.push(whiteMove)
        
        if verbose:
            print()
            print(state)
            print()
        
        result = gameOver(state)
        if (result != "*"):
            return result

        blackMove = p2.getMove(state)

        state.push(blackMove)
        
def evaluate(p1, p2, n, verbose=False):
    state = chess.Board()
    white = 0
    black = 0
    for i in range(n):
        result = play(state, p1 , p2, verbose)
        if result == "1-0":
            white += 1
        elif result == "0-1":
            black += 1
        else:
            white += .5
            black += .5
        state.reset()
    print(white,black)

# %%
#Random vs Random
p1 = randomPlayer(depth=0, heuristic=None,verbose=False)
p2 = randomPlayer(depth=0, heuristic=None,verbose=False)

evaluate(p1,p2,30)
# Out:
# 16.0 14.0

# %%
#Minimax vs Random
p1 = minimaxPlayer(depth=1, heuristic=simpleHeuristic, verbose=False)
p2 = randomPlayer(depth=0, heuristic=None, verbose=False)
evaluate(p1,p2,1)
# Out:
# 1 0

# %%
#alphabeta vs Random
p1 = alphabetaPlayer(depth=2, heuristic=simpleHeuristic, verbose=False)
p2 = randomPlayer(depth=0, heuristic=None, verbose=False)
evaluate(p1,p2,1, True)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
#
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b n r
# p p p p p p p .
# . . . . . . . .
# . . . . . . . p
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b n r
# p p p p p p p .
# . . . . . . . .
# . . . . . . N p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b n r
# p . p p p p p .
# . . . . . . . .
# . p . . . . N p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b n r
# p . p p p p p .
# . . . . . . . .
# . p . . . . N p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r n b q k b n r
# p . . p p p p .
# . . . . . . . .
# . p p . . . N p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r n b q k b n r
# p . . p p p p .
# . . . . . . . .
# . p p . . . . p
# . . . . N . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r n b q k b n r
# p . . p p . p .
# . . . . . p . .
# . p p . . . . p
# . . . . N . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r n b q k b n r
# p . . p p . p .
# . . . . . p . .
# . p N . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b q k b n r
# p . . p p . p .
# n . . . . p . .
# . p N . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b q k b n r
# p . . p p . p .
# N . . . . p . .
# . p . . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n r
# p . . p p . p .
# N . . . . p . .
# q p . . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n r
# p . . p p . p .
# . . . . . p . .
# q p N . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p r
# . . . . . p . .
# q p N . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p r
# . . . . . p . .
# q p . . . . . p
# . . . . N . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p . r
# q p . . . . . p
# . . . . N . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p . r
# q p N . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p r .
# q p N . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p r .
# q p . . . . . p
# . . . . N . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p r .
# . p . . . . . p
# . . . . N . . .
# . . . . . . . .
# P P P q P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p r .
# . p . . . . . p
# . . . . . . . .
# . . . . . . . .
# P P P N P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p r .
# . . . . . . . p
# . p . . . . . .
# . . . . . . . .
# P P P N P P P P
# R N B Q K B R .
#
#
# r . b . k b n .
# p . . p p . p .
# . . . . . p r .
# . . . . . . . p
# . p . . N . . .
# . . . . . . . .
# P P P . P P P P
# R N B Q K B R .
#
#
# r . . . k b n .
# p b . p p . p .
# . . . . . p r .
# . . . . . . . p
# . p . . N . . .
# . . . . . . . .
# P P P . P P P P
# R N B Q K B R .
#
#
# r . . . k b n .
# p b . p p . p .
# . . . . . p r .
# . . N . . . . p
# . p . . . . . .
# . . . . . . . .
# P P P . P P P P
# R N B Q K B R .
#
#
# r . . . k b n .
# p . . p p . p .
# . . . . . p r .
# . . N . . . . p
# . p . . . . . .
# . . . . . b . .
# P P P . P P P P
# R N B Q K B R .
#
#
# r . . . k b n .
# p . . Q p . p .
# . . . . . p r .
# . . N . . . . p
# . p . . . . . .
# . . . . . b . .
# P P P . P P P P
# R N B . K B R .
#
#
# r . . . . b n .
# p . . Q p k p .
# . . . . . p r .
# . . N . . . . p
# . p . . . . . .
# . . . . . b . .
# P P P . P P P P
# R N B . K B R .
#
#
# r . . . . b n .
# p . . Q p k p .
# . . . . . p r .
# . . N . . . . p
# . p . . . . . .
# . . . . . P . .
# P P P . . P P P
# R N B . K B R .
#
#
# r . . . . b n .
# p . . Q p k p .
# . . . . . p . .
# . . N . . . . p
# . p . . . . . .
# . . . . . P . .
# P P P . . P r P
# R N B . K B R .
#
#
# r . . . . b n .
# p . . . p k p .
# . . . . Q p . .
# . . N . . . . p
# . p . . . . . .
# . . . . . P . .
# P P P . . P r P
# R N B . K B R .
#
#
# r . . . . b n .
# p . . . p . p .
# . . . . Q p k .
# . . N . . . . p
# . p . . . . . .
# . . . . . P . .
# P P P . . P r P
# R N B . K B R .
#
#
# r . . . . b n .
# p . . . p . p .
# . . . . Q p k .
# . . N . . . . p
# . p . . . . . .
# . . . B . P . .
# P P P . . P r P
# R N B . K . R .
#
# 1 0

# %%
board = chess.Board()
# Out:
# True

# %%
#alphabeta w/ MCS vs Random
p1 = alphabetaPlayer(depth=2, heuristic=monteCarloHeuristic, verbose=False)
p2 = randomPlayer(depth=0, heuristic=None, verbose=False)
evaluate(p1,p2,1, True)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-3a31916268be> in <module>()
#       2 p1 = alphabetaPlayer(depth=2, heuristic=monteCarloHeuristic, verbose=False)
#       3 p2 = randomPlayer(depth=0, heuristic=None, verbose=False)
# ----> 4 evaluate(p1,p2,1, True)
#
# <ipython-input-18-a38f98dae24f> in evaluate(p1, p2, n, verbose)
#      32     black = 0
#      33     for i in range(n):
# ---> 34         result = play(state, p1 , p2, verbose)
#      35         if result == "1-0":
#      36             white += 1
#
# <ipython-input-18-a38f98dae24f> in play(state, p1, p2, verbose)
#      12         whiteMove = p1.getMove(state)
#      13
# ---> 14         state.push(whiteMove)
#      15
#      16         if verbose:
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in push(self, move)
#    1992         self.move_stack.append(move)
#    1993
# -> 1994         move = self._to_chess960(move)
#    1995
#    1996         # Reset ep square.
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in _to_chess960(self, move)
#    3517
#    3518     def _to_chess960(self, move):
# -> 3519         if move.from_square in [E1, E8] and move.to_square in [C1, G1, C8, G8] and self.piece_type_at(move.from_square) == KING and self.piece_type_at(move.to_square) != ROOK:
#    3520             if move.from_square == E1:
#    3521                 if move.to_square == G1:
#
# AttributeError: 'NoneType' object has no attribute 'from_square'

# %%
#alphabeta vs alphabeta
p1 = alphabetaPlayer(depth=2, heuristic=simpleHeuristic, verbose=False)
p2 = alphabetaPlayer(depth=2, heuristic=simpleHeuristic, verbose=False)
evaluate(p1,p2,1, True)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
#
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b n r
# p p p p p p p .
# . . . . . . . p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . N
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b n r
# p p p p p p p .
# . . . . . . . p
# . . . . . . . .
# . . . . . N . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b . r
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . N . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B . R
#
#
# r n b q k b . r
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b . r
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b . r
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p p .
# . . . . . n . p
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p . .
# . . . . . n p p
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p . .
# . . . . . n p p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b . r
# p p p p p p . .
# . . . . . n p p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b . r
# p p p p p p . .
# . . . . . n p p
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p . .
# . . . . . n p p
# . . . . . . . .
# . . . . . . . .
# . . . . . P . N
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p p p . .
# . . . . . n p p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p . p . .
# . . . . p n p p
# . . . . . . . .
# . . . . . N . .
# . . . . . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k b r .
# p p p p . p . .
# . . . . p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P . P P
# R N B Q K B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P K P P
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P K P P
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P . P P
# R N B Q . B K R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P . P P
# R N B Q . B K R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P K P P
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . .
# P P P P P K P P
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P K P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P K P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N K P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . . . . . .
# . . . N K P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . K . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . . K . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . K . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . K . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# K . . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# K . . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N . P . P
# P P P P P . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N P P . P
# P P P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N P P . P
# P P P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# K . . . . . . .
# . . . . . . . .
# . . . N P P . P
# P P P P . . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# K . . . . . . .
# . . . . . . . .
# . . . N P P . P
# P P P P . . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N P P . P
# P P P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . . . N P P . P
# P P P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k r . .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k r . .
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . r .
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . K . . . . . .
# . . . . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p p p . p . .
# . . . b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p . p . p . .
# . . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P . P P . . P .
# R N B Q . B . R
#
#
# r n b q k . . r
# p p . p . p . .
# . . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P B P P . . P .
# R N . Q . B . R
#
#
# r n b q k . r .
# p p . p . p . .
# . . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P B P P . . P .
# R N . Q . B . R
#
#
# r n b q k . r .
# p p . p . p . .
# . . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . . P P . P
# P B P P . N P .
# R N . Q . B . R
#
#
# r n b q k r . .
# p p . p . p . .
# . . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . . P P . P
# P B P P . N P .
# R N . Q . B . R
#
#
# r n b q k r . .
# p p . p . p . .
# . . p b p n p p
# . . . . . . . .
# . . . . . . . .
# . P . K P P . P
# P B P P . N P .
# R N . Q . B . R
# r . b q k r . .
# p p . p . p . .
# n . p b p n p p
# . . . . . . . .
# . . . . . . . .
# . P . K P P . P
# P B P P . N P .
# R N . Q . B . R
#
#
# r . b q k r . .
# p p . p . p . .
# n . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . . P P . P
# P B P P . N P .
# R N . Q . B . R
#
#
# r . b q k . r .
# p p . p . p . .
# n . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . . P P . P
# P B P P . N P .
# R N . Q . B . R
#
#
# r . b q k . r .
# p p . p . p . .
# n . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P B P P . . P .
# R N . Q . B . R
#
#
# r . b q k r . .
# p p . p . p . .
# n . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . N P P . P
# P B P P . . P .
# R N . Q . B . R
#
#
# r . b q k r . .
# p p . p . p . .
# n . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . . P P . P
# P B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r . .
# p p . p q p . .
# n . p b p n p p
# . . . . . . . .
# . . K . . . . .
# . P . . P P . P
# P B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r . .
# p p . p q p . .
# n . p b p n p p
# . . . . . . . .
# P . K . . . . .
# . P . . P P . P
# . B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r n .
# p p . p q p . .
# n . p b p . p p
# . . . . . . . .
# P . K . . . . .
# . P . . P P . P
# . B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r n .
# p p . p q p . .
# n . p b p . p p
# . . . . . . . .
# P . . . . . . .
# . P . K P P . P
# . B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r . .
# p p . p q p . .
# n . p b p n p p
# . . . . . . . .
# P . . . . . . .
# . P . K P P . P
# . B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r . .
# p p . p q p . .
# n . p b p n p p
# . . . . . . . .
# P . K . . . . .
# . P . . P P . P
# . B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r . .
# p p . p q p . n
# n . p b p . p p
# . . . . . . . .
# P . K . . . . .
# . P . . P P . P
# . B P P . N P .
# R N . Q . B . R
#
#
# r . b . k r . .
# p p . p q p . n
# n . p b p . p p
# . . . . . . . .
# P . . . . . . .
# . P . K P P . P
# . B P P . N P .
# R N . Q . B . R
#
#
# r . b . k . r .
# p p . p q p . n
# n . p b p . p p
# . . . . . . . .
# P . . . . . . .
# . P . K P P . P
# . B P P . N P .
# R N . Q . B . R
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-e672eaf2e604> in <module>()
#       2 p1 = alphabetaPlayer(depth=2, heuristic=simpleHeuristic, verbose=False)
#       3 p2 = alphabetaPlayer(depth=2, heuristic=simpleHeuristic, verbose=False)
# ----> 4 evaluate(p1,p2,1, True)
#
# <ipython-input-18-a38f98dae24f> in evaluate(p1, p2, n, verbose)
#      32     black = 0
#      33     for i in range(n):
# ---> 34         result = play(state, p1 , p2, verbose)
#      35         if result == "1-0":
#      36             white += 1
#
# <ipython-input-18-a38f98dae24f> in play(state, p1, p2, verbose)
#      10             return result
#      11
# ---> 12         whiteMove = p1.getMove(state)
#      13
#      14         state.push(whiteMove)
#
# <ipython-input-26-fc5a67879253> in getMove(self, state)
#     135
#     136     def getMove(self, state):
# --> 137         bestMove, bestScore = self.maxScore(state, -100, 100, self.depth)
#     138         return bestMove
#
# <ipython-input-26-fc5a67879253> in maxScore(self, state, alpha, beta, depth)
#     105         for i, move in enumerate(moves):
#     106             state.push(move)
# --> 107             testScore = self.minScore(state, alpha, beta, depth)
#     108             if testScore > alpha:
#     109                 bestMove = move
#
# <ipython-input-26-fc5a67879253> in minScore(self, state, alpha, beta, depth)
#     125         for i, move in enumerate(moves):
#     126             state.push(move)
# --> 127             testMove, testScore = self.maxScore(state, alpha, beta, depth - 1)
#     128             if testScore < beta:
#     129                 beta = testScore
#
# <ipython-input-26-fc5a67879253> in maxScore(self, state, alpha, beta, depth)
#     105         for i, move in enumerate(moves):
#     106             state.push(move)
# --> 107             testScore = self.minScore(state, alpha, beta, depth)
#     108             if testScore > alpha:
#     109                 bestMove = move
#
# <ipython-input-26-fc5a67879253> in minScore(self, state, alpha, beta, depth)
#     125         for i, move in enumerate(moves):
#     126             state.push(move)
# --> 127             testMove, testScore = self.maxScore(state, alpha, beta, depth - 1)
#     128             if testScore < beta:
#     129                 beta = testScore
#
# <ipython-input-26-fc5a67879253> in maxScore(self, state, alpha, beta, depth)
#      96 class alphabetaPlayer(player):
#      97     def maxScore(self,state, alpha, beta, depth):
# ---> 98         result = gameOver(state)
#      99         if result != "*":
#     100             return (None, reward(state, result, state.turn))
#
# <ipython-input-26-fc5a67879253> in gameOver(state)
#      35
#      36 def gameOver(state):
# ---> 37     return state.result(True)
#      38
#      39 def randomMove(state):
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in result(self, claim_draw)
#    1821
#    1822         # Draw claimed.
# -> 1823         if claim_draw and self.can_claim_draw():
#    1824             return "1/2-1/2"
#    1825
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in can_claim_draw(self)
#    1927         by threefold repetition.
#    1928         """
# -> 1929         return self.can_claim_fifty_moves() or self.can_claim_threefold_repetition()
#    1930
#    1931     def can_claim_fifty_moves(self):
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in can_claim_threefold_repetition(self)
#    1959
#    1960         # The next legal move is a threefold repetition.
# -> 1961         for move in self.generate_legal_moves():
#    1962             self.push(move)
#    1963
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in generate_non_evasions(self, from_mask, to_mask)
#    3250             from_square = to_square + (8 if self.turn == BLACK else -8)
#    3251
# -> 3252             mask = self.pin_mask(self.turn, from_square)
#    3253             if mask & BB_SQUARES[to_square]:
#    3254                 if square_rank(to_square) in [0, 7]:
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in pin_mask(self, color, square)
#    1585         sliders = self.rooks | self.bishops | self.queens
#    1586
# -> 1587         square_attackers = self.attackers_mask(not color, square)
#    1588
#    1589         for direction_masks, attack_table in [(FILE_MASK, FILE_ATTACKS),
#
# ~/Google Drive/Stanford/2017-2018/Spring/CS 221/Project/python-chess/chess/__init__.py in attackers_mask(self, color, square)
#    1508         file_pieces = FILE_MASK[bb_square] & self.occupied
#    1509         ne_pieces = DIAG_MASK_NE[bb_square] & self.occupied
# -> 1510         nw_pieces = DIAG_MASK_NW[bb_square] & self.occupied
#    1511
#    1512         parallel_sliders = self.queens | self.rooks
#
# KeyboardInterrupt:
