# %%
import sys
sys.path.append('python-chess')
import chess
import chess.uci
import random
import time
import cProfile
import numpy as np
sys.path.append('players')
import player
import evaluate
import game

# %%
def play(state, p1, p2, timeLimit, verbose = False):
    while True:
        if verbose:
            print()
            print(state)
            print()
        
        result = game.gameOver(state)
        if (result != "*"):
            return result

        whiteMove = p1.getMove(state, timeLimit)
        print(whiteMove, p1.nodes)
        state.push(whiteMove)
        
        if verbose:
            print()
            print(state)
            print()
        
        result = game.gameOver(state)
        if (result != "*"):
            return result

        blackMove = p2.getMove(state, timeLimit)
        print(blackMove, p2.nodes)

        state.push(blackMove)
        
def evaluatePlayers(p1, p2, n, timeLimit, verbose=False):
    state = chess.Board()
    white = 0
    black = 0
    for i in range(n):
        result = play(state, p1 , p2, 10, verbose)
        if result == "1-0":
            white += 1
        elif result == "0-1":
            black += 1
        else:
            white += .5
            black += .5
        state.reset()
    print(white,black)

# %%
import mtd
p1 = mtd.mtdPlayer(evaluate.combinedEvaluate, True)
p2 = player.randomPlayer(evaluate.simpleEvaluate, False)

evaluatePlayers(p1,p2, 1, 10, True)
# Out:
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
# 1 e2e3 1.0
# 2 e2e3 0.0
# 3 e2e3 1.5
# 4 e2e3 0.0
# 5 e2e3 -inf
# e2e3 11029
#
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B Q K B N R
#
# h7h5 0
#
# r n b q k b n r
# p p p p p p p .
# . . . . . . . .
# . . . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B Q K B N R
#
# 1 d1h5 3.6
# 2 f1b5 0.6000000000000001
# 3 d1f3 4.800000000000001
# 4 f1b5 -inf
# f1b5 11658
#
# r n b q k b n r
# p p p p p p p .
# . . . . . . . .
# . B . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B Q K . N R
#
# b7b6 0
#
# r n b q k b n r
# p . p p p p p .
# . p . . . . . .
# . B . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B Q K . N R
#
# 1 d1h5 4.25
# 2 d1f3 1.4000000000000001
# 3 d1f3 5.65
# 4 d1f3 0.65
# d1f3 11869
#
# r n b q k b n r
# p . p p p p p .
# . p . . . . . .
# . B . . . . . p
# . . . . . . . .
# . . . . P Q . .
# P P P P . P P P
# R N B . K . N R
#
# g8h6 0
#
# r n b q k b . r
# p . p p p p p .
# . p . . . . . n
# . B . . . . . p
# . . . . . . . .
# . . . . P Q . .
# P P P P . P P P
# R N B . K . N R
#
# 1 f3a8 7.05
# 2 f3a8 5.95
# 3 f3a8 9.25
# 4 f3a8 5.9
# f3a8 11079
#
# Q n b q k b . r
# p . p p p p p .
# . p . . . . . n
# . B . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K . N R
#
# b8c6 0
#
# Q . b q k b . r
# p . p p p p p .
# . p n . . . . n
# . B . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P . P P P
# R N B . K . N R
#
# 1 a8c6 11.3
# 2 g1e2 5.9
# 3 b5c6 10.45
# 4 g1e2 7.4
# g1e2 7596
#
# Q . b q k b . r
# p . p p p p p .
# . p n . . . . n
# . B . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# g7g6 0
#
# Q . b q k b . r
# p . p p p p . .
# . p n . . . p n
# . B . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# 1 a8c6 11.4
# 2 e2f4 6.3
# 3 b5c6 10.85
# 4 b5c6 8.2
# 5 b5c6 -inf
# b5c6 10062
#
# Q . b q k b . r
# p . p p p p . .
# . p B . . . p n
# . . . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# c8a6 0
#
# Q . . q k b . r
# p . p p p p . .
# b p B . . . p n
# . . . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# 1 a8d8 21.6
# 2 a8d8 9.6
# 3 c6d7 18.45
# 4 c6d7 8.35
# 5 c6d7 18.75
# c6d7 11717
#
# Q . . q k b . r
# p . p B p p . .
# b p . . . . p n
# . . . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# e8d7 0
#
# Q . . q . b . r
# p . p k p p . .
# b p . . . . p n
# . . . . . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# 1 a8d8 18.45
# 2 a8d5 8.35
# 3 a8d5 18.75
# 4 a8d5 7.4
# a8d5 10148
#
# . . . q . b . r
# p . p k p p . .
# b p . . . . p n
# . . . Q . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# d7c8 0
#
# . . k q . b . r
# p . p . p p . .
# b p . . . . p n
# . . . Q . . . p
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# 1 d5d8 18.75
# 2 d5a8 7.05
# 3 d5a8 18.45
# 4 d5h5 8.95
# d5h5 9731
#
# . . k q . b . r
# p . p . p p . .
# b p . . . . p n
# . . . . . . . Q
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# e7e6 0
#
# . . k q . b . r
# p . p . . p . .
# b p . . p . p n
# . . . . . . . Q
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# 1 h5h6 10.35
# 2 h5e5 2.8
# 3 h5e5 8.5
# 4 h5e5 7.5
# h5e5 8347
#
# . . k q . b . r
# p . p . . p . .
# b p . . p . p n
# . . . . Q . . .
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# d8d5 0
#
# . . k . . b . r
# p . p . . p . .
# b p . . p . p n
# . . . q Q . . .
# . . . . . . . .
# . . . . P . . .
# P P P P N P P P
# R N B . K . . R
#
# 1 e5d5 18.45
# 2 e5d5 7.25

# %%
import cmd
class humanPlayer(player.player):
    def getMove(self, state, timeLimit):
        move = None
        while (move == None):
            print(state.legal_moves)
            m = input("Move: ")
            try:
                m = state.parse_san(m)
                move = m
            except ValueError:
                print("No good")
            
        return move

# %%
import mtd_extended
p1 = mtd_extended.mtdExtendedPlayer(evaluate.combinedEvaluate, True)
p2 = humanPlayer(None, False)

evaluatePlayers(p1,p2, 1, 10, True)

# %%
import alphabeta
import minimax
p1 = alphabeta.alphabetaPlayer(evaluate.combinedEvaluate, True)
p2 = minimax.minimaxPlayer(evaluate.combinedEvaluate, False)


evaluatePlayers(p1,p2, 1, 10, True)
